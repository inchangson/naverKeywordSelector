# %% [markdown]
# ### 네이버 쇼핑 키워드 인사이트
#
# #### 참고 서비스
# - 신사임당 유투브 : https://youtu.be/Z0hL9khbpIw
# - 응용 서비스 : https://whereispost.com/keyword, https://itemscout.io
#
# #### 개요
# - 키워드에 대한 검색량 데이터 수집
# - 검색어에 대한 상품등록수 수집
# - 수집한 데이터에 대한 인사이트 도출 : 예시) 경쟁률
# - 스마트 스토어를 운영한다고 생각하고 경쟁력이 낮으면서 많은 수익을 낼수 있는 키워드와 상품 찾기

# %%
import requests, json, time
import pandas as pd
import signaturehelper
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1. 키워드에 대한 검색량 데이터 수집

# %%
# API Header 관련 키 값 
BASE_URL = 'https://api.naver.com'
API_KEY = '0100000000f5597e0d6670746d1610e84af933f00a4d110978f098d0742053d8b074d2bfb6'
SECRET_KEY = 'AQAAAAD1WX4NZnB0bRYQ6Er5M/AK7oHxcJs8a57u1CdkLvFo7Q=='
CUSTOMER_ID = '2488433'

# %%
# API Header 함수
def get_header(method, uri, api_key, secret_key, customer_id):
    timestamp = str(round(time.time() * 1000))
    signature = signaturehelper.Signature.generate(timestamp, method, uri, SECRET_KEY)
    return {'Content-Type': 'application/json; charset=UTF-8', 'X-Timestamp': timestamp, 'X-API-KEY': API_KEY, 'X-Customer': str(CUSTOMER_ID), 'X-Signature': signature}

# %%
# keyword 관련 단어들에 대한 월별 검색 데이터 수집(naver API)
def keyword_master(keyword):
    # requests.get 함수 인자 값 설정(naver API 문서 참조)
    uri = '/keywordstool'
    method = 'GET'
    relkey_params = {
        'hintKeywords':f'{keyword}',
        'showDetail':1,#related keywords, monthly query count info only(0), all details(1)
    }
    response = requests.get(BASE_URL + uri, params=relkey_params, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))
    
    # response로 온 json 데이터 파싱
    datas = (response.json())["keywordList"]
    
    # 10 미만 값 처리
    for data in datas:
        if data['monthlyPcQcCnt'] == '< 10':
            data['monthlyPcQcCnt'] = 0
        if data['monthlyMobileQcCnt'] == '< 10':
            data['monthlyMobileQcCnt'] = 0
    
    # DataFrame 변환
    df = pd.DataFrame(datas)
    
    return df

# %%
keyword = "비타민"
df = keyword_master(keyword)

# %%
df.head()
# Out:
#   relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  monthlyAvePcClkCnt  \
# 0        비타민           10300               88200                13.6
# 1     건강보조식품             900                2320                 3.9
# 2      비타민세럼             710                5190                 1.3
# 3  아이오페비타민앰플              10                 140                 0.1
# 4      종합비타민           15800              101000                46.0
#
#    monthlyAveMobileClkCnt  monthlyAvePcCtr  monthlyAveMobileCtr  plAvgDepth  \
# 0                   331.8             0.15                 0.43          15
# 1                    12.0             0.48                 0.54          15
# 2                    31.0             0.14                 0.63          15
# 3                     0.7             0.55                 0.50          14
# 4                   979.6             0.34                 1.07          15
#
#   compIdx
# 0      높음
# 1      높음
# 2      높음
# 3      높음
# 4      높음

# %%
# 상위 20개 값만 추출
df = df.head(20)

# %% [markdown]
# #### 2. 검색어에 대한 상품등록수 수집
# - item_count : 등록된 상품수
# - total_search_count : PC, Mobile 을 합친 검색량

# %%
# 정적데이터-html 수집용 
from bs4 import BeautifulSoup

# %%
def item_count(keyword):
    # 대상 페이지 설정
    url = f"https://search.shopping.naver.com/search/all?query={keyword}&cat_id=&frm=NVSHATC"
    response = requests.get(url)
    # html에서 전체 상품 수 추출 위한 BeatifulSoup 객체 생성
    dom = BeautifulSoup(response.text, "html.parser")
    # span.subFilter_num__2x0jq의 첫 번째 값이 전체 상품 수
    element = dom.select_one("span.subFilter_num__2x0jq")
    # keyword에 해당하는 상품 수가 없을 경우 count 0으로 설정
    try:
        count = int(element.text.replace(",", ""))        
    except:
        count = 0
    return count

# %%
# 기존 DataFrame에서 필요한 column들만 추출
result_df = df[['relKeyword', 'monthlyPcQcCnt', 'monthlyMobileQcCnt']]

# %%
# relKeyword에 따른 총 상품 수(item_count) 열 생성
result_df['item_count'] = result_df['relKeyword'].apply(item_count)

# %%
# PC, Moblie 합계(total_search_count) 열 생성
result_df['total_search_count'] = result_df['monthlyPcQcCnt'] + result_df['monthlyMobileQcCnt']

# %%
result_df
# Out:
#     relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0          비타민           10300               88200     2817089
# 1       건강보조식품             900                2320     2410973
# 2        비타민세럼             710                5190       51093
# 3    아이오페비타민앰플              10                 140         105
# 4        종합비타민           15800              101000      562856
# 5      주름개선화장품             820                5250       65206
# 6   난소화성말토덱스트린            1370                4440         825
# 7      바르는비타민C              70                 750         465
# 8      레드프로폴리스             360                3880        6988
# 9          건기식            1890                2230        4821
# 10       멀티비타민            9440               46400      564967
# 11      비타민씨앰플             110                1250         973
# 12      건강기능식품            7370                7960      312095
# 13     건강식품브랜드             120                 170       32843
# 14     종합비타민추천            2060               14200      562822
# 15         홍경천            1100                8230       14174
# 16      비타민에센스              80                 790       28415
# 17      기능성화장품            1920                1380       83301
# 18     프로폴리스효능            2430               28800        2857
# 19     영양제선물세트              70                 300       98501
#
#     total_search_count
# 0                98500
# 1                 3220
# 2                 5900
# 3                  150
# 4               116800
# 5                 6070
# 6                 5810
# 7                  820
# 8                 4240
# 9                 4120
# 10               55840
# 11                1360
# 12               15330
# 13                 290
# 14               16260
# 15                9330
# 16                 870
# 17                3300
# 18               31230
# 19                 370

# %% [markdown]
# #### 3. 경쟁률
# - 아이템수/검색수 : 높을수록 경쟁이 심한 상품 키워드

# %%
# 검색 대비 아이템 비율(competition_rate) 열 생성
# 해당 열은 경쟁률의 의미를 가짐
result_df['competition_rate'] = result_df['item_count']/result_df['total_search_count']

# %%
# 경쟁률이 낮은 순으로 아이템 정렬
result_df.sort_values(by='competition_rate', inplace=True, ignore_index=True)

# %%
result_df
# Out:
#     relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0      프로폴리스효능            2430               28800        2857
# 1   난소화성말토덱스트린            1370                4440         825
# 2      바르는비타민C              70                 750         465
# 3    아이오페비타민앰플              10                 140         105
# 4       비타민씨앰플             110                1250         973
# 5          건기식            1890                2230        4821
# 6          홍경천            1100                8230       14174
# 7      레드프로폴리스             360                3880        6988
# 8        종합비타민           15800              101000      562856
# 9        비타민세럼             710                5190       51093
# 10       멀티비타민            9440               46400      564967
# 11     주름개선화장품             820                5250       65206
# 12      건강기능식품            7370                7960      312095
# 13      기능성화장품            1920                1380       83301
# 14         비타민           10300               88200     2817089
# 15      비타민에센스              80                 790       28415
# 16     종합비타민추천            2060               14200      562822
# 17     건강식품브랜드             120                 170       32843
# 18     영양제선물세트              70                 300       98501
# 19      건강보조식품             900                2320     2410973
#
#     total_search_count  competition_rate
# 0                31230          0.091483
# 1                 5810          0.141997
# 2                  820          0.567073
# 3                  150          0.700000
# 4                 1360          0.715441
# 5                 4120          1.170146
# 6                 9330          1.519185
# 7                 4240          1.648113
# 8               116800          4.818973
# 9                 5900          8.659831
# 10               55840         10.117604
# 11                6070         10.742339
# 12               15330         20.358447
# 13                3300         25.242727
# 14               98500         28.599888
# 15                 870         32.660920
# 16               16260         34.613899
# 17                 290        113.251724
# 18                 370        266.218919
# 19                3220        748.749379

# %% [markdown]
# #### 인사이트 1
# - 고객층 선호도 파악
# - 키워드 별 PC, Mobile 유입 비율
# - 위 dataframe의 상위 keyword 위주로 선정 시 경쟁률에서 우위를 점할 수 있음

# %% [markdown]
# #### 인사이트 2
# - 고객층 선호도 파악
# - 키워드 별 PC, Mobile 유입 비율

# %%
# PC 대비 모바일 비율(competition_rate) 열 생성
result_df['mobile_per_pc'] = result_df['monthlyMobileQcCnt']/result_df['monthlyPcQcCnt']

# %%
result_df.sort_values(by='mobile_per_pc', inplace=True, ignore_index=True, ascending=False)

# %%
result_df
# Out:
#     relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0    아이오페비타민앰플              10                 140         105
# 1      프로폴리스효능            2430               28800        2857
# 2       비타민씨앰플             110                1250         973
# 3      레드프로폴리스             360                3880        6988
# 4      바르는비타민C              70                 750         465
# 5       비타민에센스              80                 790       28415
# 6          비타민           10300               88200     2817089
# 7          홍경천            1100                8230       14174
# 8        비타민세럼             710                5190       51093
# 9      종합비타민추천            2060               14200      562822
# 10     주름개선화장품             820                5250       65206
# 11       종합비타민           15800              101000      562856
# 12       멀티비타민            9440               46400      564967
# 13     영양제선물세트              70                 300       98501
# 14  난소화성말토덱스트린            1370                4440         825
# 15      건강보조식품             900                2320     2410973
# 16     건강식품브랜드             120                 170       32843
# 17         건기식            1890                2230        4821
# 18      건강기능식품            7370                7960      312095
# 19      기능성화장품            1920                1380       83301
#
#     total_search_count  competition_rate  mobile_per_pc
# 0                  150          0.700000      14.000000
# 1                31230          0.091483      11.851852
# 2                 1360          0.715441      11.363636
# 3                 4240          1.648113      10.777778
# 4                  820          0.567073      10.714286
# 5                  870         32.660920       9.875000
# 6                98500         28.599888       8.563107
# 7                 9330          1.519185       7.481818
# 8                 5900          8.659831       7.309859
# 9                16260         34.613899       6.893204
# 10                6070         10.742339       6.402439
# 11              116800          4.818973       6.392405
# 12               55840         10.117604       4.915254
# 13                 370        266.218919       4.285714
# 14                5810          0.141997       3.240876
# 15                3220        748.749379       2.577778
# 16                 290        113.251724       1.416667
# 17                4120          1.170146       1.179894
# 18               15330         20.358447       1.080054
# 19                3300         25.242727       0.718750
